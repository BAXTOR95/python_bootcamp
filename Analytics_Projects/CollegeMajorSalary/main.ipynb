# %% [markdown]
# # College Major VS Your Salary

# %%
import pandas as pd
df = pd.read_csv('salaries_by_college_major.csv')
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# ### Reading the data

# %%
df.head()
# Out:
#      Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0             Accounting                 46000.0                   77100.0
# 1  Aerospace Engineering                 57700.0                  101000.0
# 2            Agriculture                 42600.0                   71900.0
# 3           Anthropology                 36800.0                   61500.0
# 4           Architecture                 41600.0                   76800.0
#
#    Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 0                            42200.0                           152000.0
# 1                            64300.0                           161000.0
# 2                            36300.0                           150000.0
# 3                            33800.0                           138000.0
# 4                            50600.0                           136000.0
#
#       Group
# 0  Business
# 1      STEM
# 2  Business
# 3      HASS
# 4  Business

# %%
df.shape
# Out:
# (51, 6)

# %%
df.columns
# Out:
# Index(['Undergraduate Major', 'Starting Median Salary',
#        'Mid-Career Median Salary', 'Mid-Career 10th Percentile Salary',
#        'Mid-Career 90th Percentile Salary', 'Group'],
#       dtype='object')

# %%
df.isna()
# Out:
#     Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0                 False                   False                     False
# 1                 False                   False                     False
# 2                 False                   False                     False
# 3                 False                   False                     False
# 4                 False                   False                     False
# 5                 False                   False                     False
# 6                 False                   False                     False
# 7                 False                   False                     False
# 8                 False                   False                     False
# 9                 False                   False                     False
# 10                False                   False                     False
# 11                False                   False                     False
# 12                False                   False                     False
# 13                False                   False                     False
# 14                False                   False                     False
# 15                False                   False                     False
# 16                False                   False                     False
# 17                False                   False                     False
# 18                False                   False                     False
# 19                False                   False                     False
# 20                False                   False                     False
# 21                False                   False                     False
# 22                False                   False                     False
# 23                False                   False                     False
# 24                False                   False                     False
# 25                False                   False                     False
# 26                False                   False                     False
# 27                False                   False                     False
# 28                False                   False                     False
# 29                False                   False                     False
# 30                False                   False                     False
# 31                False                   False                     False
# 32                False                   False                     False
# 33                False                   False                     False
# 34                False                   False                     False
# 35                False                   False                     False
# 36                False                   False                     False
# 37                False                   False                     False
# 38                False                   False                     False
# 39                False                   False                     False
# 40                False                   False                     False
# 41                False                   False                     False
# 42                False                   False                     False
# 43                False                   False                     False
# 44                False                   False                     False
# 45                False                   False                     False
# 46                False                   False                     False
# 47                False                   False                     False
# 48                False                   False                     False
# 49                False                   False                     False
# 50                False                    True                      True
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 0                               False                              False
# 1                               False                              False
# 2                               False                              False
# 3                               False                              False
# 4                               False                              False
# 5                               False                              False
# 6                               False                              False
# 7                               False                              False
# 8                               False                              False
# 9                               False                              False
# 10                              False                              False
# 11                              False                              False
# 12                              False                              False
# 13                              False                              False
# 14                              False                              False
# 15                              False                              False
# 16                              False                              False
# 17                              False                              False
# 18                              False                              False
# 19                              False                              False
# 20                              False                              False
# 21                              False                              False
# 22                              False                              False
# 23                              False                              False
# 24                              False                              False
# 25                              False                              False
# 26                              False                              False
# 27                              False                              False
# 28                              False                              False
# 29                              False                              False
# 30                              False                              False
# 31                              False                              False
# 32                              False                              False
# 33                              False                              False
# 34                              False                              False
# 35                              False                              False
# 36                              False                              False
# 37                              False                              False
# 38                              False                              False
# 39                              False                              False
# 40                              False                              False
# 41                              False                              False
# 42                              False                              False
# 43                              False                              False
# 44                              False                              False
# 45                              False                              False
# 46                              False                              False
# 47                              False                              False
# 48                              False                              False
# 49                              False                              False
# 50                               True                               True
#
#     Group
# 0   False
# 1   False
# 2   False
# 3   False
# 4   False
# 5   False
# 6   False
# 7   False
# 8   False
# 9   False
# 10  False
# 11  False
# 12  False
# 13  False
# 14  False
# 15  False
# 16  False
# 17  False
# 18  False
# 19  False
# 20  False
# 21  False
# 22  False
# 23  False
# 24  False
# 25  False
# 26  False
# 27  False
# 28  False
# 29  False
# 30  False
# 31  False
# 32  False
# 33  False
# 34  False
# 35  False
# 36  False
# 37  False
# 38  False
# 39  False
# 40  False
# 41  False
# 42  False
# 43  False
# 44  False
# 45  False
# 46  False
# 47  False
# 48  False
# 49  False
# 50   True

# %%
df.tail()
# Out:
#       Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 46             Psychology                 35900.0                   60400.0
# 47               Religion                 34100.0                   52000.0
# 48              Sociology                 36500.0                   58200.0
# 49                Spanish                 34000.0                   53100.0
# 50  Source: PayScale Inc.                     NaN                       NaN
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary Group
# 46                            31600.0                           127000.0  HASS
# 47                            29700.0                            96400.0  HASS
# 48                            30700.0                           118000.0  HASS
# 49                            31000.0                            96400.0  HASS
# 50                                NaN                                NaN   NaN

# %%
clean_df = df.dropna()
clean_df.tail()
# Out:
#    Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 45   Political Science                 40800.0                   78200.0
# 46          Psychology                 35900.0                   60400.0
# 47            Religion                 34100.0                   52000.0
# 48           Sociology                 36500.0                   58200.0
# 49             Spanish                 34000.0                   53100.0
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary Group
# 45                            41200.0                           168000.0  HASS
# 46                            31600.0                           127000.0  HASS
# 47                            29700.0                            96400.0  HASS
# 48                            30700.0                           118000.0  HASS
# 49                            31000.0                            96400.0  HASS

# %% [markdown]
# ### Find College Major with Highest Starting Salaries

# %%
idx = clean_df['Starting Median Salary'].idxmax()
clean_df['Undergraduate Major'][idx]
# Out:
# 'Physician Assistant'

# %%
clean_df.loc[idx]
# Out:
# Undergraduate Major                  Physician Assistant
# Starting Median Salary                           74300.0
# Mid-Career Median Salary                         91700.0
# Mid-Career 10th Percentile Salary                66400.0
# Mid-Career 90th Percentile Salary               124000.0
# Group                                               STEM
# Name: 43, dtype: object

# %% [markdown]
# ### What college major has the highest mid-career salary? How much do graduates with this major earn?

# %%
idx = clean_df['Mid-Career Median Salary'].idxmax()
clean_df.loc[idx]
# Out:
# Undergraduate Major                  Chemical Engineering
# Starting Median Salary                            63200.0
# Mid-Career Median Salary                         107000.0
# Mid-Career 10th Percentile Salary                 71900.0
# Mid-Career 90th Percentile Salary                194000.0
# Group                                                STEM
# Name: 8, dtype: object

# %% [markdown]
# ### Which college major has the lowest starting salary and how much do graduates earn after university?

# %%
idx = clean_df['Starting Median Salary'].idxmin()
clean_df.loc[idx]
# Out:
# Undergraduate Major                  Spanish
# Starting Median Salary               34000.0
# Mid-Career Median Salary             53100.0
# Mid-Career 10th Percentile Salary    31000.0
# Mid-Career 90th Percentile Salary    96400.0
# Group                                   HASS
# Name: 49, dtype: object

# %% [markdown]
# ### Which college major has the lowest mid-career salary and how much can people expect to earn with this degree?

# %%
idx = clean_df['Mid-Career Median Salary'].idxmin()
clean_df.loc[idx]
# Out:
# Undergraduate Major                  Education
# Starting Median Salary                 34900.0
# Mid-Career Median Salary               52000.0
# Mid-Career 10th Percentile Salary      29300.0
# Mid-Career 90th Percentile Salary     102000.0
# Group                                     HASS
# Name: 18, dtype: object

# %% [markdown]
# ### Majors with the Most Potential vs Lowest Risk

# %% [markdown]
# #### Lowest Risk Majors

# %%
spread_col = clean_df['Mid-Career 90th Percentile Salary'] - clean_df['Mid-Career 10th Percentile Salary']
clean_df.insert(1, 'Spread', spread_col)
clean_df.head()
# Out:
#      Undergraduate Major    Spread  Starting Median Salary  \
# 0             Accounting  109800.0                 46000.0
# 1  Aerospace Engineering   96700.0                 57700.0
# 2            Agriculture  113700.0                 42600.0
# 3           Anthropology  104200.0                 36800.0
# 4           Architecture   85400.0                 41600.0
#
#    Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# 0                   77100.0                            42200.0
# 1                  101000.0                            64300.0
# 2                   71900.0                            36300.0
# 3                   61500.0                            33800.0
# 4                   76800.0                            50600.0
#
#    Mid-Career 90th Percentile Salary     Group
# 0                           152000.0  Business
# 1                           161000.0      STEM
# 2                           150000.0  Business
# 3                           138000.0      HASS
# 4                           136000.0  Business

# %%
low_risk = clean_df.sort_values('Spread')
low_risk[['Undergraduate Major', 'Spread']].head()
# Out:
#            Undergraduate Major   Spread
# 40                     Nursing  50700.0
# 43         Physician Assistant  57600.0
# 41                   Nutrition  65300.0
# 49                     Spanish  65400.0
# 27  Health Care Administration  66400.0

# %% [markdown]
# #### Degrees with the highest potential

# %%
highest_potential = clean_df.sort_values('Mid-Career 90th Percentile Salary', ascending=False)
highest_potential[['Undergraduate Major', 'Mid-Career 90th Percentile Salary']].head()
# Out:
#      Undergraduate Major  Mid-Career 90th Percentile Salary
# 17             Economics                           210000.0
# 22               Finance                           195000.0
# 8   Chemical Engineering                           194000.0
# 37                  Math                           183000.0
# 44               Physics                           178000.0

# %% [markdown]
# #### Degrees with the greatest spread in salaries. Which majors have the largest difference between high and low earners after graduation

# %%
high_spread = clean_df.sort_values('Spread', ascending=False)
high_spread[['Undergraduate Major', 'Spread']].head()
# Out:
#    Undergraduate Major    Spread
# 17           Economics  159400.0
# 22             Finance  147800.0
# 37                Math  137800.0
# 36           Marketing  132900.0
# 42          Philosophy  132500.0

# %%
high_spread = clean_df.sort_values('Mid-Career Median Salary', ascending=False)
high_spread[['Undergraduate Major', 'Mid-Career Median Salary']].head()
# Out:
#        Undergraduate Major  Mid-Career Median Salary
# 8     Chemical Engineering                  107000.0
# 12    Computer Engineering                  105000.0
# 19  Electrical Engineering                  103000.0
# 1    Aerospace Engineering                  101000.0
# 17               Economics                   98600.0

# %% [markdown]
# ### Which category of degrees has the highest average salary? Is it STEM, Business or HASS (Humanities, Arts, and Social Science)?

# %%
clean_df.groupby('Group').count()
# Out:
#           Undergraduate Major  Spread  Starting Median Salary  \
# Group
# Business                   12      12                      12
# HASS                       22      22                      22
# STEM                       16      16                      16
#
#           Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# Group
# Business                        12                                 12
# HASS                            22                                 22
# STEM                            16                                 16
#
#           Mid-Career 90th Percentile Salary
# Group
# Business                                 12
# HASS                                     22
# STEM                                     16

# %% [markdown]
# #### Average salary by group

# %%
# Specify the numeric columns for mean calculation
numeric_columns = [
    'Spread',
    'Starting Median Salary',
    'Mid-Career Median Salary',
    'Mid-Career 10th Percentile Salary',
    'Mid-Career 90th Percentile Salary',
]
clean_df.groupby('Group')[numeric_columns].mean()
# Out:
#              Spread  Starting Median Salary  Mid-Career Median Salary  \
# Group
# Business 103,958.33               44,633.33                 75,083.33
# HASS      95,218.18               37,186.36                 62,968.18
# STEM     101,600.00               53,862.50                 90,812.50
#
#           Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary
# Group
# Business                          43,566.67                         147,525.00
# HASS                              34,145.45                         129,363.64
# STEM                              56,025.00                         157,625.00

# %% [markdown]
# ## Using Data from [Payscale](https://www.payscale.com/college-salary-report/majors-that-pay-you-back/bachelors)

# %%
LINK = 'https://www.payscale.com/college-salary-report/majors-that-pay-you-back/bachelors'
COLUMN_NAMES = ["Rank", "Major", "Type", "EarlyCareerPay", "MidCareerPay", "HighMeaning"]
table_from_html = pd.read_html(LINK)
original_df = table_from_html[0]
original_df.columns = COLUMN_NAMES
original_df
# Out:
#        Rank                                              Major  \
# 0    Rank:1                        Major:Petroleum Engineering
# 1    Rank:2  Major:Operations Research & Industrial Enginee...
# 2    Rank:3                           Major:Interaction Design
# 3    Rank:4             Major:Applied Economics and Management
# 4    Rank:5                             Major:Building Science
# 5    Rank:6                        Major:Actuarial Mathematics
# 6    Rank:6                          Major:Operations Research
# 7    Rank:8                          Major:Systems Engineering
# 8    Rank:9                Major:Optical Science & Engineering
# 9   Rank:10               Major:Information & Computer Science
# 10  Rank:11                   Major:Aeronautics & Astronautics
# 11  Rank:12                            Major:Aerospace Studies
# 12  Rank:13                                     Major:Pharmacy
# 13  Rank:14                            Major:Cognitive Science
# 14  Rank:15                         Major:Managerial Economics
# 15  Rank:16                       Major:Quantitative Economics
# 16  Rank:17                                 Major:Econometrics
# 17  Rank:18                              Major:Foreign Affairs
# 18  Rank:19                         Major:Chemical Engineering
# 19  Rank:20                            Major:Public Accounting
# 20  Rank:21                            Major:Political Economy
# 21  Rank:22               Major:Corporate Accounting & Finance
# 22  Rank:23                            Major:Actuarial Science
# 23  Rank:24                    Major:Computer Engineering (CE)
# 24  Rank:25                 Major:Electrical Power Engineering
#
#                      Type            EarlyCareerPay             MidCareerPay  \
# 0   Degree Type:Bachelors  Early Career Pay:$97,500  Mid-Career Pay:$212,500
# 1   Degree Type:Bachelors  Early Career Pay:$98,300  Mid-Career Pay:$191,800
# 2   Degree Type:Bachelors  Early Career Pay:$74,700  Mid-Career Pay:$173,600
# 3   Degree Type:Bachelors  Early Career Pay:$76,500  Mid-Career Pay:$164,400
# 4   Degree Type:Bachelors  Early Career Pay:$69,000  Mid-Career Pay:$163,100
# 5   Degree Type:Bachelors  Early Career Pay:$70,700  Mid-Career Pay:$160,000
# 6   Degree Type:Bachelors  Early Career Pay:$92,200  Mid-Career Pay:$160,000
# 7   Degree Type:Bachelors  Early Career Pay:$87,000  Mid-Career Pay:$159,100
# 8   Degree Type:Bachelors  Early Career Pay:$79,600  Mid-Career Pay:$158,300
# 9   Degree Type:Bachelors  Early Career Pay:$76,000  Mid-Career Pay:$157,800
# 10  Degree Type:Bachelors  Early Career Pay:$88,200  Mid-Career Pay:$156,900
# 11  Degree Type:Bachelors  Early Career Pay:$62,600  Mid-Career Pay:$154,300
# 12  Degree Type:Bachelors  Early Career Pay:$69,400  Mid-Career Pay:$154,000
# 13  Degree Type:Bachelors  Early Career Pay:$78,000  Mid-Career Pay:$153,800
# 14  Degree Type:Bachelors  Early Career Pay:$74,700  Mid-Career Pay:$153,300
# 15  Degree Type:Bachelors  Early Career Pay:$74,500  Mid-Career Pay:$152,700
# 16  Degree Type:Bachelors  Early Career Pay:$72,000  Mid-Career Pay:$152,100
# 17  Degree Type:Bachelors  Early Career Pay:$62,900  Mid-Career Pay:$152,000
# 18  Degree Type:Bachelors  Early Career Pay:$85,600  Mid-Career Pay:$151,800
# 19  Degree Type:Bachelors  Early Career Pay:$69,700  Mid-Career Pay:$151,200
# 20  Degree Type:Bachelors  Early Career Pay:$73,100  Mid-Career Pay:$150,600
# 21  Degree Type:Bachelors  Early Career Pay:$76,800  Mid-Career Pay:$149,600
# 22  Degree Type:Bachelors  Early Career Pay:$76,700  Mid-Career Pay:$149,000
# 23  Degree Type:Bachelors  Early Career Pay:$89,100  Mid-Career Pay:$148,500
# 24  Degree Type:Bachelors  Early Career Pay:$84,700  Mid-Career Pay:$148,300
#
#            HighMeaning
# 0   % High Meaning:61%
# 1   % High Meaning:21%
# 2   % High Meaning:54%
# 3   % High Meaning:54%
# 4   % High Meaning:47%
# 5   % High Meaning:52%
# 6   % High Meaning:57%
# 7   % High Meaning:58%
# 8   % High Meaning:73%
# 9   % High Meaning:63%
# 10  % High Meaning:56%
# 11    % High Meaning:-
# 12  % High Meaning:79%
# 13  % High Meaning:43%
# 14  % High Meaning:38%
# 15  % High Meaning:43%
# 16  % High Meaning:35%
# 17  % High Meaning:32%
# 18  % High Meaning:55%
# 19  % High Meaning:47%
# 20  % High Meaning:31%
# 21  % High Meaning:50%
# 22  % High Meaning:42%
# 23  % High Meaning:46%
# 24  % High Meaning:72%

# %%
# Add rest of the tables from other pages to the dataframe
for page_no in range(2, 33):
    table_from_html = pd.read_html(LINK + f'/page/{page_no}')
    page_df = table_from_html[0]
    page_df.columns = COLUMN_NAMES
    original_df = pd.concat([original_df, page_df], ignore_index=True)

# %%
# Select necessary columns only
new_df = original_df[["Major", "EarlyCareerPay", "MidCareerPay"]].copy()
new_df
# Out:
#                                                  Major  \
# 0                          Major:Petroleum Engineering
# 1    Major:Operations Research & Industrial Enginee...
# 2                             Major:Interaction Design
# 3               Major:Applied Economics and Management
# 4                               Major:Building Science
# ..                                                 ...
# 794                               Major:Equine Studies
# 795                        Major:Addictions Counseling
# 796                     Major:Nonprofit Administration
# 797                    Major:Early Childhood Education
# 798                                Major:Metalsmithing
#
#                EarlyCareerPay             MidCareerPay
# 0    Early Career Pay:$97,500  Mid-Career Pay:$212,500
# 1    Early Career Pay:$98,300  Mid-Career Pay:$191,800
# 2    Early Career Pay:$74,700  Mid-Career Pay:$173,600
# 3    Early Career Pay:$76,500  Mid-Career Pay:$164,400
# 4    Early Career Pay:$69,000  Mid-Career Pay:$163,100
# ..                        ...                      ...
# 794  Early Career Pay:$40,300   Mid-Career Pay:$52,500
# 795  Early Career Pay:$45,900   Mid-Career Pay:$52,200
# 796  Early Career Pay:$42,800   Mid-Career Pay:$52,100
# 797  Early Career Pay:$41,700   Mid-Career Pay:$50,600
# 798  Early Career Pay:$44,700   Mid-Career Pay:$44,900
#
# [799 rows x 3 columns]

# %%
# Clean columns
new_df.replace({"^Major:": "", "^Early Career Pay:\$": "", "^Mid-Career Pay:\$": "", ",": ""}, regex=True, inplace=True)
new_df
# Out:
#                                             Major EarlyCareerPay MidCareerPay
# 0                           Petroleum Engineering          97500       212500
# 1    Operations Research & Industrial Engineering          98300       191800
# 2                              Interaction Design          74700       173600
# 3                Applied Economics and Management          76500       164400
# 4                                Building Science          69000       163100
# ..                                            ...            ...          ...
# 794                                Equine Studies          40300        52500
# 795                         Addictions Counseling          45900        52200
# 796                      Nonprofit Administration          42800        52100
# 797                     Early Childhood Education          41700        50600
# 798                                 Metalsmithing          44700        44900
#
# [799 rows x 3 columns]

# %%
# Change datatype of numeric columns
new_df[['EarlyCareerPay', 'MidCareerPay']] = new_df[['EarlyCareerPay', 'MidCareerPay']].apply(pd.to_numeric)

# %%
new_df.nlargest(5, 'EarlyCareerPay')
# Out:
#                                             Major  EarlyCareerPay  \
# 56                    Physician Assistant Studies          109600
# 1    Operations Research & Industrial Engineering           98300
# 0                           Petroleum Engineering           97500
# 117          Nuclear Engineering Technology (NET)           92500
# 6                             Operations Research           92200
#
#      MidCareerPay
# 56         136500
# 1          191800
# 0          212500
# 117        122800
# 6          160000

# %%
new_df.nlargest(5, 'MidCareerPay')
# Out:
#                                           Major  EarlyCareerPay  MidCareerPay
# 0                         Petroleum Engineering           97500        212500
# 1  Operations Research & Industrial Engineering           98300        191800
# 2                            Interaction Design           74700        173600
# 3              Applied Economics and Management           76500        164400
# 4                              Building Science           69000        163100
